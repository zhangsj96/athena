# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from scipy.interpolate import griddata
import sys
sys.path.insert(0, '../vis/python')
import athena_read

# %%
foldername = './'
ishift_min, ishift_max = 0, 42  # Set your range here

fig, axs = plt.subplots(2, 1, figsize=(8, 8))
pcm1 = axs[0].pcolormesh(np.zeros((2,2)), np.zeros((2,2)), np.zeros((2,2)), vmin=20, vmax=100)
pcm2 = axs[1].pcolormesh(np.zeros((2,2)), np.zeros((2,2)), np.zeros((2,2)), vmin=20, vmax=100)
cb1 = fig.colorbar(pcm1, ax=axs[0], label='Temperature (K)')
cb2 = fig.colorbar(pcm2, ax=axs[1], label='Temperature (K)')
axs[0].set_xlabel('r (code units)')
axs[0].set_ylabel('pi/2-theta (radians)')
axs[1].set_xlabel('r (code units)')
axs[1].set_ylabel('phi (radians)')

def update(ishift):
    filename = f'dsharp.out1.{ishift:05}.athdf'
    data = athena_read.athdf(foldername + filename)
    data['temp'] = data['press']/data['rho']*6.14e3

    axs[0].cla()
    axs[1].cla()
    pcm1 = axs[0].pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][0])
    axs[0].set_xlabel('r (code units)')
    axs[0].set_ylabel('pi/2-theta (radians)')
    axs[0].set_title(f'ishift={ishift}')
    #fig.colorbar(pcm1, ax=axs[0], label='Temperature (K)')

    pcm2 = axs[1].pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:])
    axs[1].set_xlabel('r (code units)')
    axs[1].set_ylabel('phi (radians)')
    #fig.colorbar(pcm2, ax=axs[1], label='Temperature (K)')

ani = FuncAnimation(fig, update, frames=range(ishift_min, ishift_max+1), repeat=False)
plt.tight_layout()
ani.save('movie.mp4', writer='ffmpeg')

# %%
np.pi/2.-1.2458
# Out:
# 0.32499632679489654

# %%
np.pi/2.+np.pi/2.-1.2458
# Out:
# 1.895792653589793

# %%
np.logspace(np.log10(0.5), np.log10(2.0), 256+1)
# Out:
# array([0.5       , 0.50271495, 0.50544464, 0.50818916, 0.51094857,
#        0.51372297, 0.51651244, 0.51931705, 0.52213689, 0.52497204,
#        0.52782259, 0.53068861, 0.5335702 , 0.53646743, 0.5393804 ,
#        0.54230918, 0.54525387, 0.54821454, 0.55119129, 0.55418421,
#        0.55719337, 0.56021888, 0.56326081, 0.56631926, 0.56939432,
#        0.57248607, 0.57559461, 0.57872004, 0.58186243, 0.58502188,
#        0.5881985 , 0.59139236, 0.59460356, 0.5978322 , 0.60107837,
#        0.60434216, 0.60762368, 0.61092302, 0.61424027, 0.61757553,
#        0.62092891, 0.62430049, 0.62769038, 0.63109868, 0.63452548,
#        0.63797089, 0.64143501, 0.64491794, 0.64841978, 0.65194063,
#        0.65548061, 0.6590398 , 0.66261832, 0.66621627, 0.66983376,
#        0.67347089, 0.67712777, 0.68080451, 0.68450121, 0.68821799,
#        0.69195494, 0.69571219, 0.69948984, 0.703288  , 0.70710678,
#        0.7109463 , 0.71480667, 0.718688  , 0.7225904 , 0.726514  ,
#        0.7304589 , 0.73442522, 0.73841307, 0.74242258, 0.74645386,
#        0.75050703, 0.75458221, 0.75867952, 0.76279908, 0.766941  ,
#        0.77110541, 0.77529244, 0.7795022 , 0.78373482, 0.78799042,
#        0.79226913, 0.79657108, 0.80089638, 0.80524517, 0.80961757,
#        0.81401371, 0.81843372, 0.82287774, 0.82734588, 0.83183829,
#        0.83635509, 0.84089642, 0.8454624 , 0.85005318, 0.85466888,
#        0.85930965, 0.86397562, 0.86866692, 0.87338369, 0.87812608,
#        0.88289422, 0.88768825, 0.89250831, 0.89735454, 0.90222708,
#        0.90712609, 0.91205169, 0.91700404, 0.92198328, 0.92698956,
#        0.93202302, 0.93708382, 0.94217209, 0.94728799, 0.95243167,
#        0.95760328, 0.96280297, 0.9680309 , 0.97328721, 0.97857206,
#        0.98388561, 0.98922801, 0.99459942, 1.        , 1.0054299 ,
#        1.01088929, 1.01637831, 1.02189715, 1.02744595, 1.03302488,
#        1.0386341 , 1.04427378, 1.04994409, 1.05564518, 1.06137723,
#        1.0671404 , 1.07293487, 1.0787608 , 1.08461836, 1.09050773,
#        1.09642908, 1.10238258, 1.10836841, 1.11438674, 1.12043775,
#        1.12652162, 1.13263852, 1.13878863, 1.14497214, 1.15118923,
#        1.15744007, 1.16372486, 1.17004377, 1.17639699, 1.18278471,
#        1.18920712, 1.19566439, 1.20215673, 1.20868432, 1.21524736,
#        1.22184603, 1.22848054, 1.23515106, 1.24185781, 1.24860098,
#        1.25538076, 1.26219735, 1.26905096, 1.27594178, 1.28287002,
#        1.28983587, 1.29683955, 1.30388127, 1.31096121, 1.3180796 ,
#        1.32523664, 1.33243255, 1.33966752, 1.34694179, 1.35425555,
#        1.36160902, 1.36900242, 1.37643597, 1.38390988, 1.39142438,
#        1.39897967, 1.40657599, 1.41421356, 1.4218926 , 1.42961334,
#        1.437376  , 1.44518081, 1.453028  , 1.46091779, 1.46885043,
#        1.47682615, 1.48484517, 1.49290773, 1.50101407, 1.50916443,
#        1.51735904, 1.52559815, 1.533882  , 1.54221083, 1.55058488,
#        1.5590044 , 1.56746964, 1.57598085, 1.58453827, 1.59314215,
#        1.60179276, 1.61049033, 1.61923514, 1.62802742, 1.63686745,
#        1.64575548, 1.65469177, 1.66367658, 1.67271018, 1.68179283,
#        1.6909248 , 1.70010635, 1.70933776, 1.7186193 , 1.72795123,
#        1.73733384, 1.74676739, 1.75625216, 1.76578844, 1.77537649,
#        1.78501661, 1.79470908, 1.80445417, 1.81425218, 1.82410339,
#        1.83400809, 1.84396657, 1.85397913, 1.86404605, 1.87416763,
#        1.88434418, 1.89457598, 1.90486334, 1.91520656, 1.92560594,
#        1.93606179, 1.94657442, 1.95714412, 1.96777122, 1.97845603,
#        1.98919885, 2.        ])

# %%
0.50271495/0.5
# Out:
# 1.0054299

# %%
# !ls ..
# Out:
# 2d_test		  CITATION.cff	      inputs	   src
# 2d_test_nocolort  CODE_OF_CONDUCT.md  LICENSE	   tst
# 2d_test_stanley   configure.log       Makefile	   vis
# 2d_test_two_bins  configure.py	      Makefile.in  wd_adv_rad
# athenawd	  CONTRIBUTING.md     obj	   wd_adv_rad_test
# bin		  CPPLINT.cfg	      README.md    wd_high_spatial_res
# CHANGELOG.md	  doc		      setup.cfg    wd_test_opac

# %%
ishift = 1
foldername = '../wd_high_spatial_res/'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][0], vmin=15, vmax=90)
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,63,:], vmin=15, vmax=90)
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# Text(0, 0.5, 'phi (radians)')

# %%
np.log10(0.5)
# Out:
# np.float64(-0.3010299956639812)

# %%
10**0.15
# Out:
# 1.4125375446227544

# %%
ishift = 46
foldername = './'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][0], vmin=15, vmax=40)
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:], vmin=15, vmax=40)
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 4
#       2 foldername = './'
#       3 filename = f'./dsharp.out1.{0+ishift:05}.athdf'
# ----> 4 data = athena_read.athdf(foldername+filename )
#       5 data['temp'] = data['press']/data['rho']*6.14e3
#       6 plt.subplot(2, 1, 1)
#
# File /appalachia/d4/shjzhang/athena_devel/athena/wd_adv_rad/../vis/python/athena_read.py:397, in athdf(filename, raw, data, quantities, dtype, level, return_levels, subsample, fast_restrict, x1_min, x1_max, x2_min, x2_max, x3_min, x3_max, vol_func, vol_params, face_func_1, face_func_2, face_func_3, center_func_1, center_func_2, center_func_3, num_ghost)
#     394     new_data = False
#     396 # Open file
# --> 397 with h5py.File(filename, 'r') as f:
#     398     # Extract size information
#     399     max_level = f.attrs['MaxLevel']
#     400     if level is None:
#
# File ~/miniconda3/envs/daily/lib/python3.12/site-packages/h5py/_hl/files.py:564, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     555     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     556                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     557                      alignment_threshold=alignment_threshold,
#     558                      alignment_interval=alignment_interval,
#     559                      meta_block_size=meta_block_size,
#     560                      **kwds)
#     561     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     562                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     563                      fs_page_size=fs_page_size)
# --> 564     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     566 if isinstance(libver, tuple):
#     567     self._libver = libver
#
# File ~/miniconda3/envs/daily/lib/python3.12/site-packages/h5py/_hl/files.py:238, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     236     if swmr and swmr_support:
#     237         flags |= h5f.ACC_SWMR_READ
# --> 238     fid = h5f.open(name, flags, fapl=fapl)
#     239 elif mode == 'r+':
#     240     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py/_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = '././dsharp.out1.00046.athdf', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %%
ishift = 100
foldername = './'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][0])
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:])
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# Text(0, 0.5, 'phi (radians)')

# %%
plt.contourf(data['x1v'], data['x3v'], data['temp'][:,31,:])
plt.colorbar(label='Temperature (K)')
plt.semilogx()
# Out:
# []

# %%
#ishift = 2
#foldername = './'
#filename = f'./dsharp.out1.{0+ishift:05}.athdf'
#data = athena_read.athdf(foldername+filename )
#data['temp'] = data['press']/data['rho']*6.14e3
for i in range(3):
    plt.subplot(2, 2, i+1)
    plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], np.log10(data[f'Sigma_a_{i}'][0]/data['rho'][0]), )
    plt.text(0.05, 0.6, f'Sigma_a_{i}/rho', transform=plt.gca().transAxes, fontsize=12, color='white')
    #plt.colorbar(label='Temperature (K)')
    #plt.xlabel('r (code units)')
    #plt.ylabel('pi/2-theta (radians)')

# %%
#ishift = 2
#foldername = './'
#filename = f'./dsharp.out1.{0+ishift:05}.athdf'
#data = athena_read.athdf(foldername+filename )
#data['temp'] = data['press']/data['rho']*6.14e3
for i in range(3):
    plt.subplot(2, 2, i+1)
    plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], np.log10(data[f'Er_{i}'][0]), )
    plt.text(0.05, 0.9, f'Er_{i}', transform=plt.gca().transAxes, fontsize=12, color='white')
    #plt.colorbar(label='Temperature (K)')
    #plt.xlabel('r (code units)')
    #plt.ylabel('pi/2-theta (radians)')

# %%
#ishift = 2
#foldername = './'
#filename = f'./dsharp.out1.{0+ishift:05}.athdf'
#data = athena_read.athdf(foldername+filename )
#data['temp'] = data['press']/data['rho']*6.14e3
for i in range(3):
    plt.subplot(2, 2, i+1)
    plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], np.log10(data[f'Sigma_a_{i}'][0]/data['rho'][0]), )
    plt.text(0.05, 0.6, f'Sigma_a_{i}/rho', transform=plt.gca().transAxes, fontsize=12, color='white')
    #plt.colorbar(label='Temperature (K)')
    #plt.xlabel('r (code units)')
    #plt.ylabel('pi/2-theta (radians)')

# %%
i = 2
plt.plot(np.pi/2.-data['x2v'], np.log10(data[f'Sigma_a_{i}'][50,:,50]/data['rho'][50,:,50]), )

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 31, 80], '+')
plt.plot(data['x3v'], data['temp'][:, 31+10, 80], '+')
plt.plot(data['x3v'], data['temp'][:, 31+20, 80], '+')

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 31, 10], '+')
plt.plot(data['x3v'], data['temp'][:, 31, 40], '+')
plt.plot(data['x3v'], data['temp'][:, 31, 90], '+')

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
128/32
# Out:
# 4.0

# %%
256/32
# Out:
# 8.0

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 15, 40], '+')
plt.plot(data['x3v'], data['temp'][:, 10, 40], '+')
plt.plot(data['x3v'], data['temp'][:, 5, 40], '+')

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
(np.pi/2.- 1.2458) / 16
# Out:
# 0.020312270424681034

# %%
np.pi*2./0.02
# Out:
# 314.1592653589793

# %%
32                # Number of zones in X2-direction
x2min            = 1.2458

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 15, 40])
plt.plot(data['x3v'], data['temp'][:, 10, 40])
plt.plot(data['x3v'], data['temp'][:, 5, 40])

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 15, 40])
plt.plot(data['x3v'], data['temp'][:, 10, 40])
plt.plot(data['x3v'], data['temp'][:, 5, 40])

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
ishift = 6
foldername = './'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][7])
plt.colorbar(label='Temperature (K)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:])
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# Text(0, 0.5, 'phi (radians)')

# %%
ishift = 6
foldername = './'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][7])
plt.colorbar(label='Temperature (K)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:])
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# Text(0, 0.5, 'phi (radians)')

# %%
ishift = 6
foldername = './'
filename = f'./dsharp.out1.{0+ishift:05}.athdf'
data = athena_read.athdf(foldername+filename )
data['temp'] = data['press']/data['rho']*6.14e3
plt.subplot(2, 1, 1)
plt.pcolormesh(data['x1v'], np.pi/2.-data['x2v'], data['temp'][7])
plt.colorbar(label='Temperature (K)')
plt.ylabel('pi/2-theta (radians)')

plt.subplot(2, 1, 2)
plt.pcolormesh(data['x1v'], data['x3v'], data['temp'][:,15,:])
plt.colorbar(label='Temperature (K)')
plt.xlabel('r (code units)')
plt.ylabel('phi (radians)')
# Out:
# Text(0, 0.5, 'phi (radians)')

# %%
#plt.plot(data['x3v'], data['temp'][:, 15, 11])
#plt.plot(data['x3v'], data['temp'][:, 15, 31])
#plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.plot(data['x3v'], data['temp'][:, 15, 60])

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
plt.plot(data['x3v'], data['temp'][:, 15, 60])
plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')

# %%
plt.plot(data['x3v'], data['temp'][:, 15, 11])
plt.plot(data['x3v'], data['temp'][:, 15, 31])
plt.plot(data['x3v'], data['temp'][:, 15, 60])

plt.ylabel('Temperature (K)')
plt.xlabel('phi (radians)')
plt.twinx()
plt.plot(data['x3v'], 0.5*(1.+np.sin(data['x3v'])) )
plt.ylabel('(1+sin(phi))/2')
plt.axvline(x=np.pi/2., color='k', linestyle='--')
plt.axvline(x=3.*np.pi/2., color='k', linestyle='--')
